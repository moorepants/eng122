# %% [markdown]
# # Python
#
# Write a function `rescale` that takes a list as input and returns a corresponding array of values scaled to lie in the range 0.0 to 1.0. (Hint: If $L$ and $H$ are the lowest and highest values in the original array, then the replacement for a value $v$ should be $(v-L) / (H-L)$.) For example,
#
# ```python
# rescale([1.0, 3.0, 5.0])
# ```
#
# should return
#
# ```python
# [0.0, 0.5, 1.0]
# ```

# %% [markdown]
# # NumPy
#
# Rewrite your `rescale` function so that it works with NumPy arrays instead of Python lists. Use vectorized operations inside the function instead of loops.
#
# This should work:
#
# ```python
# rescale(np.array([[1.0, 3.0, 5.0],
#                   [2.0, 4.0, 6.0]])
# ```
# and give:
# ```python
# array([[ 0. ,  0.5,  1. ],
#        [ 0. ,  0.5,  1. ]])
# ```

# %% [markdown]
# # Matplotlib
#
# Create a graph of the function $f(x) = A e^{\tau t} \cos(\omega t + \phi)$ where $A=3.0$, $\tau=-0.2$, and $\phi=\pi/3$. Plot a different color line for $\omega=1, 3$, and $5$. Make sure to include a legend for each line and axis labels.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

A = 3
tau = -0.2
phi = np.pi / 3
omega = np.array([[1], [3], [5]])
t = np.linspace(0, 10, 1000)
plt.plot(t, np.transpose(A * np.exp(tau * t) * np.cos(omega * t + phi)))
plt.legend(['$\omega=1$', '$\omega=3$', '$\omega=5$'])
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # SciPy
#
# Using the $\omega=1$ curve from the the Matplotlib section and use `scipy.interpolate.interp1d` to interpolate the function at half second intervals. Create a new plot with the interpolated points shown superimposed over the curve. Make the plot interactive using a function so that you have a slider that lets you adjust the interpolation interval. Use the graph to make an estimate of the largest interval needed to recognize that the curve is a decaying sine wave.

# %%
from scipy.interpolate import interp1d
from ipywidgets import interact

# note that interact doesn't work with notebook backend
# %matplotlib inline

plt.figure()

def plot(interval=0.5):
    A = 3
    tau = -0.2
    phi = np.pi / 3
    omega = 1
    t = np.linspace(0, 10, 1000)
    y = A * np.exp(tau * t) * np.cos(omega * t + phi)
    
    interp_func = interp1d(t, y)
    new_t = np.arange(0, 10, interval)
    plt.plot(t, y)
    plt.plot(new_t, interp_func(new_t), marker='o')
    plt.xlabel('Time [s]')
    plt.ylabel('Amplitude')    

interact(plot, interval=(0.1, 5.0))

# %% [markdown]
# Some of these exercises have been modified from the CC-BY Software Carpentry Lessons.
